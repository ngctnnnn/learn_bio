# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Bước 1: đọc dữ liệu

# %%
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
# unique items
# Out:
# array([ 19000,  20000,  43000,  57000,  76000,  58000,  84000, 150000,
#         33000,  65000,  80000,  52000,  86000,  18000,  82000,  25000,
#         26000,  28000,  29000,  22000,  49000,  41000,  23000,  30000,
#         74000, 137000,  16000,  44000,  90000,  27000,  72000,  31000,
#         17000,  51000, 108000,  15000,  79000,  54000, 135000,  89000,
#         32000,  83000,  55000,  48000, 117000,  87000,  66000, 120000,
#         63000,  68000, 113000, 112000,  42000,  88000,  62000, 118000,
#         85000,  81000,  50000, 116000, 123000,  73000,  37000,  59000,
#        149000,  21000,  35000,  71000,  61000,  75000,  53000, 107000,
#         96000,  45000,  47000, 100000,  38000,  69000, 148000, 115000,
#         34000,  60000,  70000,  36000,  39000, 134000, 101000, 130000,
#        114000, 142000,  78000, 143000,  91000, 144000, 102000, 126000,
#        133000, 147000, 104000, 146000, 122000,  97000,  95000, 131000,
#         77000, 125000, 106000, 141000,  93000, 138000, 119000, 105000,
#         99000, 129000,  46000,  64000, 139000])

# %%
# age analysis

# %%
# salary analysis

# %% [markdown]
# ## Bước 2: Chia tập train, test

# %%
# Out:
# ((320, 3), (80, 3))

# %% [markdown]
# ## Bước 3: Chuẩn hóa dữ liệu

# %%
# Out:
# array([[ 0.84438499, -1.3100333 ],
#        [ 0.10410226,  0.21547855],
#        [ 0.6593143 , -1.21850259],
#        [ 1.02945567,  0.24598879],
#        [ 0.01156692,  0.42905021],
#        [ 1.02945567, -1.15748212],
#        [-1.8391399 ,  0.49007068],
#        [ 0.93692033,  1.61894945],
#        [ 0.28917294, -0.63880809],
#        [-0.35857445, -1.24901283],
#        [ 0.38170828,  0.42905021],
#        [ 0.38170828,  1.1612959 ],
#        [ 0.38170828, -0.36421595],
#        [-0.63618047,  0.15445807],
#        [ 0.75184965, -1.34054354],
#        [ 0.01156692,  0.15445807],
#        [-1.00632183,  0.73415258],
#        [-1.28392786, -1.43207425],
#        [-0.17350376,  1.83252111],
#        [-1.09885717,  0.45956045],
#        [ 0.1966376 , -0.57778761],
#        [-0.35857445, -0.69982856],
#        [-0.26603911,  1.28333685],
#        [-0.26603911,  0.18496831],
#        [-1.19139252, -1.00493093],
#        [-1.09885717, -1.52360496],
#        [-1.28392786, -0.24217501],
#        [ 0.28917294,  0.18496831],
#        [-0.54364513,  0.61211163],
#        [-1.56153388,  0.06292736],
#        [ 0.38170828, -0.36421595],
#        [-0.45110979, -0.69982856],
#        [ 0.84438499, -0.51676714],
#        [ 1.95480908, -1.12697188],
#        [-1.8391399 ,  0.06292736],
#        [ 1.67720306,  1.1612959 ],
#        [ 2.04734442, -0.7303388 ],
#        [-0.26603911, -0.39472619],
#        [ 0.6593143 , -1.34054354],
#        [ 0.1966376 , -0.27268524],
#        [-1.3764632 , -0.08962382],
#        [ 0.28917294, -0.42523643],
#        [-0.72871581,  1.52741874],
#        [ 1.30706169, -0.85237975],
#        [-1.00632183, -1.06595141],
#        [-0.35857445, -0.69982856],
#        [-1.74660456,  0.58160139],
#        [-0.63618047, -1.46258449],
#        [ 0.28917294,  0.18496831],
#        [-0.08096842,  0.42905021],
#        [-1.74660456,  0.30700926],
#        [ 0.01156692, -0.33370572],
#        [-1.65406922, -0.91340022],
#        [ 1.95480908,  2.35119514],
#        [-0.45110979, -1.15748212],
#        [ 0.1966376 , -0.18115453],
#        [ 0.10410226,  2.07660301],
#        [ 0.1966376 ,  0.27649902],
#        [ 0.75184965, -0.76084904],
#        [ 0.47424362,  1.40537779],
#        [ 1.02945567,  2.29017467],
#        [ 0.38170828,  0.73415258],
#        [-0.63618047,  1.58843922],
#        [-1.00632183, -0.24217501],
#        [ 1.49213237,  1.28333685],
#        [-0.26603911, -0.4862569 ],
#        [-0.26603911, -0.57778761],
#        [-0.26603911, -0.21166477],
#        [ 0.28917294,  0.18496831],
#        [ 0.93692033, -0.76084904],
#        [-1.46899854, -1.18799235],
#        [-1.65406922,  0.49007068],
#        [ 0.38170828,  0.21547855],
#        [ 0.84438499, -0.45574667],
#        [ 1.95480908,  1.95456206],
#        [-0.17350376,  2.38170538],
#        [-0.91378649, -1.03544117],
#        [ 2.04734442, -0.9744207 ],
#        [ 0.10410226,  0.917214  ],
#        [ 1.86227374, -0.57778761]])

# %% [markdown]
# # Bước 4: Khởi tạo và huấn luyện mô hình

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %% [markdown]
# ## Logistic Regression

# %%
# Out:
# Accuracy score of Logistic Regression: 0.9

# %% [markdown]
# ## Logistic K-fold

# %%
# Out:
# Accuracy score of Logistic with K-Fold: 0.8450000000000001

# %% [markdown]
# ## K-Nearest Neighbor

# %%
# Out:
# Accuracy score of KNN: 0.8875

# %% [markdown]
# ## K-Nearest K-fold

# %%
# Out:
# Accuracy score of KNN with K-Fold: 0.8950000000000001

# %% [markdown]
# ## SVM

# %%
# Out:
# Accuracy score of SVM: 0.9125

# %% [markdown]
# ## SVM K-fold

# %%
# Out:
# Accuracy score of SVM with K-Fold: 0.9075

# %% [markdown]
# ## Kernel SVM

# %%
# Out:
# Accuracy score of Kernel SVM: 0.8875

# %% [markdown]
# ## Kernel SVM K-fold

# %%
# Out:
# Accuracy score of Kernel SVM with K-Fold: 0.8425

# %% [markdown]
# ## Naive Bayes

# %%
# Out:
# Accuracy score of Kernel SVM: 0.9

# %% [markdown]
# ## Naive Bayes K-fold

# %%
# Out:
# Accuracy score of Naive Bayes with K-Fold: 0.8899999999999999

# %% [markdown]
# ## Decision Tree

# %%
# Out:
# Accuracy score of Decision Tree: 0.8

# %% [markdown]
# ## Decision Tree K-fold

# %%
# Out:
# Accuracy score of Decision Tree with K-Fold: 0.8474999999999999

# %% [markdown]
# ## Random Forest

# %%
# Out:
# Accuracy score of Random Forest: 0.8875

# %% [markdown]
# ## Random Forest K-fold

# %%
# Out:
# Accuracy score of Random Forest with K-Fold: 0.915
